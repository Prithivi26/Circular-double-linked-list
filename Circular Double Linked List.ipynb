# %% [markdown]
# # Circular Double Linked List

# %%
# create a node

class Node:
    def __init__(self,data):
        self.data = data
        self.prev = None
        self.next = None

class CDLL:
    def __init__(self):
        self.head = None
        self.tail = None

    # inserting node at beginning
    def n_b(self,data):
        nb = Node(data)
        nb.next = self.head
        self.head.prev = nb
        self.head = nb
        self.tail.next = nb

    
    # inserting node at end
    def n_e(self,data):
        ne = Node(data)
        temp = self.head
        self.tail.next = ne
        self.tail = ne
        self.tail.next = self.head

    # inserting node at specific position
    def n_sp(self,pos,data):
        np = Node(data)
        temp = self.head
        for i in range (pos-1):
            temp = temp.next
        np.next = temp.next
        temp.next.prev = np
        np.prev = temp
        temp.next = np

    # deleting node at beginning
    def d_b(self):
        temp = self.head
        self.head = temp.next
        self.tail.next = self.head
        temp.next = None
        self.head.prev = None

     # deleting node at end
    def d_e(self):
        before = self.head 
        temp = self.head.next
        while temp.next!=self.tail:
            temp = temp.next
            before = before.next
        self.tail.next = None
        self.tail = temp
        self.tail.next = self.head

    # deleting node at specific position
    def d_sp(self,pos):
        before = self.head
        temp = self.head.next
        for i in range(pos-1):
            temp = temp.next
            before = before.next
        before.next = temp.next
        temp.next.prev = before
        temp.prev = None
        temp.next = None

     
    # displaying
    def display(self):
        if self.head == None and self.tail == None:
            print("Empty")
        else:
            temp = self.head
            print(temp.data,end="<->")
            while temp.next!= self.head:
                temp = temp.next
                print(temp.data,end="<->")
            print(temp.next.data)


        
# creating objects for links
L = CDLL()
print("\nBefore creating nodes, CDLL be:",end=" ")
L.display()
print()

# creating objects for Nodes
n1 = Node(10)
L.head = n1
L.tail = n1
n1.next = n1
n1.prev = n1
print("\nAfter creating 1st node, CDLL be:",end=" ")
L.display()
print()

n2 = Node(20)
n1.next = n2
L.tail = n2
n2.prev = n1
n1.prev = n2
n2.next = n1
print("\nAfter creating 2nd node, CDLL be:",end=" ")
L.display()
print()

n3 = Node(30)
n2.next = n3
L.tail = n3
n3.prev = n2
n1.prev = n3
n3.next = n1
print("\nAfter creating 3rd node, CDLL be:",end=" ")
L.display()
print()

L.n_b(5)
print("\nAfter inserting node at beginning , CDLL be:",end=" ")
L.display()
print()

L.n_e(35)
print("\nAfter inserting node at end , CDLL be:",end=" ")
L.display()
print()

L.n_sp(3, 25)
print("\nAfter inserting node at specific position , CDLL be:",end=" ")
L.display()
print()

L.d_b()
print("\nAfter deleting node at beginning , CDLL be:",end=" ")
L.display()
print()

L.d_e()
print("\nAfter deleting node at end , CDLL be:",end=" ")
L.display()
print()

L.d_sp(2)
print("\nAfter deleting node at specific position , CDLL be:",end=" ")
L.display()
print()
# Out:
# Before creating nodes, CDLL be: Empty
#
#
# After creating 1st node, CDLL be: 10<->10
#
#
# After creating 2nd node, CDLL be: 10<->20<->10
#
#
# After creating 3rd node, CDLL be: 10<->20<->30<->10
#
#
# After inserting node at beginning , CDLL be: 5<->10<->20<->30<->5
#
#
# After inserting node at end , CDLL be: 5<->10<->20<->30<->35<->5
#
#
# After inserting node at specific position , CDLL be: 5<->10<->20<->25<->30<->35<->5
#
#
# After deleting node at beginning , CDLL be: 10<->20<->25<->30<->35<->10
#
#
# After deleting node at end , CDLL be: 10<->20<->25<->30<->10
#
#
# After deleting node at specific position , CDLL be: 10<->20<->30<->10

# %%
# create a node

class Node:
    def __init__(self,data):
        self.data = data
        self.prev = None
        self.next = None

class CDLL:
    def __init__(self):
        self.head = None
        self.tail = None

     # searching
    def searching(self,search):
        temp = self.head
        while temp.next!=None:
            if temp.data == search:
                print(search,"Searched Data is found")
                break
            temp =temp.next
        else:
            print(search,"Searching value is not found")


     
    # displaying
    def display(self):
        if self.head == None and self.tail == None:
            print("Empty")
        else:
            temp = self.head
            print(temp.data,end="<->")
            while temp.next!= self.head:
                temp = temp.next
                print(temp.data,end="<->")
            print(temp.next.data)


    
    
# creating objects for links
L = CDLL()
print("\nBefore creating nodes, CDLL be:",end=" ")
L.display()
print()

# creating objects for Nodes
n1 = Node(10)
L.head = n1
L.tail = n1
n1.next = n1
n1.prev = n1
print("\nAfter creating 1st node, CDLL be:",end=" ")
L.display()
print()

n2 = Node(20)
n1.next = n2
L.tail = n2
n2.prev = n1
n1.prev = n2
n2.next = n1
print("\nAfter creating 2nd node, CDLL be:",end=" ")
L.display()
print()

n3 = Node(17)
n2.next = n3
L.tail = n3
n3.prev = n2
n1.prev = n3
n3.next = n1
print("\nAfter creating 3rd node, CDLL be:",end=" ")
L.display()
print()

n4 = Node(83)
n3.next = n4
L.tail = n4
n4.prev = n3
n1.prev = n4
n4.next = n1
print("\nAfter creating 4th node, CDLL be:",end=" ")
L.display()
print()

n5 = Node(77)
n4.next = n5
L.tail = n5
n5.prev = n4
n1.prev = n5
n5.next = n1
print("\nAfter creating 5th node, CDLL be:",end=" ")
L.display()
print()

print()
L.searching(77)
# Out:
# Before creating nodes, CDLL be: Empty
#
#
# After creating 1st node, CDLL be: 10<->10
#
#
# After creating 2nd node, CDLL be: 10<->20<->10
#
#
# After creating 3rd node, CDLL be: 10<->20<->17<->10
#
#
# After creating 4th node, CDLL be: 10<->20<->17<->83<->10
#
#
# After creating 5th node, CDLL be: 10<->20<->17<->83<->77<->10
#
#
# 77 Searched Data is found
